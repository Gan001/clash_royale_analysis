# %%
import requests
import pandas as pd
import pandas_profiling

# %%
url = "https://api.royaleapi.com/endpoints"
headers = {
    'auth': "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6MzIxNywiaWRlbiI6IjYzNzczNzE1NDgyNjQ2OTQwNiIsIm1kIjp7InVzZXJuYW1lIjoiRWR3aW4iLCJkaXNjcmltaW5hdG9yIjoiMDYzNyIsImtleVZlcnNpb24iOjN9LCJ0cyI6MTU3MjY1NDQ3MzQ5NX0.F7ozvmtBbuZQt7dLtmFqWRXt8z7QJbgHLMC5o7oPWe0"
    }

# %%
response = requests.request("GET", url, headers=headers)

data = response.json()

# %%
data
# Out:
# {'CLAN': {'key': 'CLAN', 'name': 'Clan', 'path': '/clan/{tag}'},
#  'CLANS': {'key': 'CLANS', 'name': 'Clans', 'path': '/clans/{tags}'},
#  'CLAN_BATTLES': {'key': 'CLAN_BATTLES',
#   'name': 'Clan Battles',
#   'path': '/clan/{tag}/battles'},
#  'CLAN_HISTORY': {'key': 'CLAN_HISTORY',
#   'name': 'Clan History',
#   'path': '/clan/{tag}/history'},
#  'CLAN_HISTORY_WEEKLY': {'key': 'CLAN_HISTORY_WEEKLY',
#   'name': 'Clan History Weekly',
#   'path': '/clan/{tag}/history/weekly'},
#  'CLAN_SEARCH': {'key': 'CLAN_SEARCH',
#   'name': 'Clan Search',
#   'path': '/clan/search'},
#  'CLAN_TRACK': {'key': 'CLAN_TRACK',
#   'name': 'Clan Track',
#   'path': '/clan/{tag}/track'},
#  'CLAN_TRACKING': {'key': 'CLAN_TRACKING',
#   'name': 'Clan Tracking',
#   'path': '/clan/{tag}/tracking'},
#  'CLAN_WAR': {'key': 'CLAN_WAR',
#   'name': 'Clan War',
#   'path': '/clan/{tag}/war'},
#  'CLAN_WARLOG': {'key': 'CLAN_WARLOG',
#   'name': 'Clan WarLog',
#   'path': '/clan/{tag}/warlog'},
# ...

# %% [markdown]
# # Top Clans

# %%
url_clans = "https://api.royaleapi.com/top/clans/All"
headers_clans = {
    'auth': "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6MzIxNywiaWRlbiI6IjYzNzczNzE1NDgyNjQ2OTQwNiIsIm1kIjp7InVzZXJuYW1lIjoiRWR3aW4iLCJkaXNjcmltaW5hdG9yIjoiMDYzNyIsImtleVZlcnNpb24iOjN9LCJ0cyI6MTU3MjY1NDQ3MzQ5NX0.F7ozvmtBbuZQt7dLtmFqWRXt8z7QJbgHLMC5o7oPWe0"
    }

# %%
response_clans = requests.request("GET", url_clans, headers=headers_clans)

data_clans = response_clans.json()

# %%
len(data_clans)
# Out:
# 1000

# %%
data_clans[:1]
# Out:
# [{'tag': 'PPCLCJG9',
#   'name': 'AK Syndicate',
#   'score': 64281,
#   'rank': 1,
#   'previousRank': 1,
#   'memberCount': 50,
#   'badge': {'id': 16000044,
#    'name': 'Star_Shine_03',
#    'category': '01_Symbol',
#    'image': 'https://royaleapi.github.io/cr-api-assets/badges/Star_Shine_03.png'},
#   'location': {'name': 'United States', 'isCountry': True, 'code': 'US'}}]

# %%
Tags = []
Name = []
Score = []
Rank = []

# %%
for data in data_clans[:999]:
    tags = data['tag']
    name = data['name']
    score = data['score']
    rank = data['rank']
    Tags.append(tags)
    Name.append(name)
    Score.append(score)
    Rank.append(rank)

# %%
df = pd.DataFrame(
    {'Tags': Tags,
     'Name': Name,
     'Score': Score,
     'Rank' : Rank
    })

# %%
df.head()
# Out:
#        Tags          Name  Score  Rank
# 0  PPCLCJG9  AK Syndicate  64281     1
# 1   YVPQV8V          CSL1  64051     2
# 2   2LVRQ29    Midwinter™  63871     3
# 3  2PQGVRU9     襲撃のダイナマイト  63751     4
# 4  PRGCGGP0    Shark clan  63719     5

# %%
df.to_csv('../data/Top_Clans.csv')

# %%
for tag in df['Tags']:
# Out:
# PPCLCJG9
# YVPQV8V
# 2LVRQ29
# 2PQGVRU9
# PRGCGGP0
# 8UJULRQG
# PJYCYJPG
# PYGQQC2P
# 8VG2C9CJ
# P8JLV8JL
# PGLQ0VQ
# 2LRU2J
# YCQCRQPU
# 2CRP0URJ
# 9JCLGG9G
# 9Y8YVJYP
# PGPV0GG
# 82UV9LV
# Y8LCJJQU
# 8VCVPC28
# PQQJC889
# 99Y9PJUY
# 9PJ82CRC
# YPUG8PP
# 8G9VY92
# CQVV2PJ
# PLYJ0UL9
# 2LUJ09CC
# PLYVU2G
# 20JJCCG
# L2CLC9VP
# 82CP0UVP
# 8JJJPUPV
# P00R0GQQ
# 9JJRCUUY
# 9QU9298C
# YPULPQRQ
# 2CQQVQCU
# 8Q8R9LQ0
# YY22Q2CR
# L09LP
# 90R02YY9
# YGC8C2PY
# 2PQR0U
# 9800PPPG
# 9RC08U9G
# 2V0QU2QC
# 9YGJC8LU
# P8G2JQ0R
# 9QY9JG09
# 2YCU22JQ
# Y0YCV0YP
# YYL2GJUC
# 2RYG90QL
# 89JQ02Q9
# PQUC20
# YJ8LQV22
# 8RU0JYQ8
# PPRYY2RC
# Q8YRPV
# UYPU9
# YP8VRRUV
# 9Q00GCVR
# P8RCUUL2
# Y8GLLUQ
# 8YVV9YUR
# 98RJUQJQ
# 9QGQQGPU
# VQCP8J2
# 89UJ8J2J
# 8GQGUJ
# P9GRQ89P
# 9RP0LL0Q
# 2L0VV9J8
# 8VVJ8RG8
# P0PYC2UR
# PUR9CLCP
# 9U2G2C8L
# PQ0JQ890
# 9VQJ0YUJ
# 2C0LVR9P
# 2YG28L9R
# 8LQ2P0RL
# P02RPQLU
# YQVJ9L
# RRQ2UCY
# 90U8CQCC
# 9LP9VCJ8
# P2YJ0QC0
# Y9JQVJL
# 8C88C2
# L0QPV
# 9J9VULLP
# 80UVUP22
# ...

# %%
url_clan_battles = f'https://api.royaleapi.com//clan/9PJ82CRC/battles'
headers_clan_battles = {
    'auth': "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6MzIxNywiaWRlbiI6IjYzNzczNzE1NDgyNjQ2OTQwNiIsIm1kIjp7InVzZXJuYW1lIjoiRWR3aW4iLCJkaXNjcmltaW5hdG9yIjoiMDYzNyIsImtleVZlcnNpb24iOjN9LCJ0cyI6MTU3MjY1NDQ3MzQ5NX0.F7ozvmtBbuZQt7dLtmFqWRXt8z7QJbgHLMC5o7oPWe0"
    }

# %%
response_clan_battles = requests.request("GET", url_clan_battles, headers=headers_clan_battles)

data_clan_battles = response_clan_battles.json()

# %%
data_clan_battles
# Out:
# [{'type': 'clanMate',
#   'utcTime': '2019-11-08T23:49:02Z',
#   'deckType': 'collection',
#   'winCountBefore': 0,
#   'teamSize': 1,
#   'winner': -1,
#   'teamCrowns': 0,
#   'opponentCrowns': 1,
#   'trophyChange': 0,
#   'arena': {'id': 18,
#    'name': 'Master III',
#    'arena': 'Master III',
#    'trophyLimit': 5600},
#   'mode': {'id': 72000007,
#    'name': 'Friendly',
#    'cardLevelAdjustment': '',
#    'deckSelection': '',
#    'overtimeSeconds': 0,
#    'sameDeckOnBoth': False,
#    'separateTeamDecks': False,
#    'swappingTowers': False,
#    'useStartingElixir': False,
#    'randomBoosts': False,
#    'heroes': False,
#    'players': 'PvP',
#    'eventDeckClanWar': False,
#    'givesClanScore': False,
#    'fixedDeckOrder': False,
#    'heist': False,
#    'spellSupport': False,
#    'hasDarkElixirCollector': False},
#   'team': [{'tag': 'JQJYLU0',
#     'name': 'hermione',
#     'crownsEarned': 0,
#     'startTrophies': 5817,
#     'trophyChange': 0,
# ...
