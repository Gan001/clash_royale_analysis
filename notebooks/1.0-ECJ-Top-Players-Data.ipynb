# %% [markdown]
# ## Player Info

# %%
import requests
import pandas as pd
import pandas_profiling

# %%
url_play = "https://api.royaleapi.com/top/players/All"
headers_play = {
    'auth': "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6MzIxNywiaWRlbiI6IjYzNzczNzE1NDgyNjQ2OTQwNiIsIm1kIjp7InVzZXJuYW1lIjoiRWR3aW4iLCJkaXNjcmltaW5hdG9yIjoiMDYzNyIsImtleVZlcnNpb24iOjN9LCJ0cyI6MTU3MjY1NDQ3MzQ5NX0.F7ozvmtBbuZQt7dLtmFqWRXt8z7QJbgHLMC5o7oPWe0"
    }

# %%
response_play = requests.request("GET", url_play, headers=headers_play)

data_play = response_play.json()

# %%
try_df = pd.DataFrame(data_play)

# %%
try_df = try_df[['name', 'rank', 'tag']]

# %%
try_df
# Out:
#                 name  rank        tag
# 0        lemonTree68     1  929URQCL8
# 1              Xiake     2   9CQJQYP2
# 2       <c5>Ruusskov     3   8Y2LP9L2
# 3          SK Morten     4    R09228V
# 4          ⭐️ JSJ ⭐️     5   YCUQ2CUP
# 5       不爱睡觉不爱起床的小力量     6   QYYYCUC2
# 6          faisal84™     7  8Q802U2V0
# 7      <c8>A L O N E     8   PC2PP2RP
# 8            Alperen     9   2V92UCC9
# 9      WHAM! Capgun✨    10    YYJ0R0G
# 10             RUBÉN    11     LPRR9P
# 11   FENOFINALFORM⚡☠    12     8R020P
# 12              舞❤️喵    13   LGLL8LLC
# 13              ｓａｒａ    14    VLVQGC0
# 14          Sapolo11    15  298CUPLP2
# 15         Mr Milano    16   20YPVC8C
# 16            Tempus    17   YR8VGYPQ
# 17         Candy Man    18   Y9UU28YY
# 18                繁星    19   UQQCC0JC
# 19             shogi    20  9GGCQP8CJ
# 20    Aura Famouskid    21   L8P0GVQV
# 21    Ángel♥∞♥Andrea    22   89Y8CLPR
# 22                bj    23  28UCJ209G
# 23        Lim l ヌッシー    24  2V80C0YU0
# 24            Saloom    25   LPC20PY2
# 25                쿠키    26  22V8P828G
# 26     Megumi l ぱんどら    27  2CYCG0LJJ
# 27        Over BaNa❦    28  2UVV829PR
# 28            JuicyJ    29    YGGYQYV
# 29       ✨TR King♥️✨    30   PPUVRRR9
# ..               ...   ...        ...
# 970               逆境   971  8U9C8JRGJ
# 971            Joke    972    GCQUVQY
# 972            Gaara   973  88CQUJVQP
# 973  Antonio Flores✊   974   YYJVJQPQ
# 974            Messi   975  8RCPVQYU9
# 975          壽山垃圾學店仔   976   RVU80VUG
# 976      Nova I Alex   977   QQLQVGC8
# 977    Nova I sergio   978  2RJ9JY0LQ
# 978     ☺︎︎ドズルちゃん☺︎︎   979  8V9UJ90RR
# 979             だらけ隊   980  892RQ2LCU
# 980        PK I Frio   981  22V09GYRG
# 981   ⭐️abood3sh™️⭐️   982   YYJU9L0Q
# 982        Dreamyboi   983   PRCV0JUU
# 983             モンキー   984  2GJVCG9Q9
# 984               生卵   985  2L0YUC082
# 985             ヒロリン   986  82UV9J28G
# 986      けー@HIRIAGOD   987  988RPUGCV
# 987       ✨BabyBoy™️   988   QL0VL29G
# 988             lord   989   C28VJL0L
# 989         AcMiLaN™   990    C9RPVYU
# 990    ⚡JuanDiego:v⚡   991   CJJ80VL0
# 991          LaloBG™   992  2JUYVUVQ0
# 992     ✨Azt l Alan✨   993   PUQQGGCV
# 993     ♡Ŧửşɦi★ċβĕť♡   994  299Y2YCLL
# 994      MG I Victor   995  8LJYGRYG2
# 995     G.Y.J★iseven   996   Q8YC22RR
# 996          Richapa   997  2PVGPLP9G
# 997             有有有你   998  228QC2ULP
# 998   Russian l カズー™   999  2GQPGV8RR
# 999          DOMINIC  1000   L9QV0JUY
#
# [1000 rows x 3 columns]

# %%
try_df.to_csv('../data/Top_Players.csv')
