# %% [markdown]
# ## Player Info

# %%
import requests
import pandas as pd
import pandas_profiling
from Config import key

# %%
url_play = "https://api.royaleapi.com/top/players/All"
headers_play = {
    'auth': key
    }

# %%
response_play = requests.request("GET", url_play, headers=headers_play)

data_play = response_play.json()

# %%
try_df = pd.DataFrame(data_play)

# %%
try_df = try_df[['name', 'rank', 'tag']]

# %%
try_df
# Out:
#                 name  rank        tag
# 0        lemonTree68     1  929URQCL8
# 1      Black Panther     2  228Y8U28Y
# 2              Xiake     3   9CQJQYP2
# 3       <c5>Ruusskov     4   8Y2LP9L2
# 4          SK Morten     5    R09228V
# 5          ⭐️ JSJ ⭐️     6   YCUQ2CUP
# 6       不爱睡觉不爱起床的小力量     7   QYYYCUC2
# 7      Anaban❤️Snipe     8   GYUQQCLV
# 8              RUBÉN     9     LPRR9P
# 9          faisal84™    10  8Q802U2V0
# 10            Tempus    11   YR8VGYPQ
# 11     <c8>A L O N E    12   PC2PP2RP
# 12           Alperen    13   2V92UCC9
# 13     WHAM! Capgun✨    14    YYJ0R0G
# 14   FENOFINALFORM⚡☠    15     8R020P
# 15              舞❤️喵    16   LGLL8LLC
# 16    Aura Famouskid    17   L8P0GVQV
# 17              ｓａｒａ    18    VLVQGC0
# 18          العدواني    19   9PVRYCCR
# 19         Mr Milano    20   20YPVC8C
# 20         Candy Man    21   Y9UU28YY
# 21                繁星    22   UQQCC0JC
# 22             shogi    23  9GGCQP8CJ
# 23    Ángel♥∞♥Andrea    24   89Y8CLPR
# 24        Lim l ヌッシー    25  2V80C0YU0
# 25            Saloom    26   LPC20PY2
# 26       ⭐BastSardo⭐    27    VL2LU00
# 27                쿠키    28  22V8P828G
# 28     Megumi l ぱんどら    29  2CYCG0LJJ
# 29          Sapolo11    30  298CUPLP2
# ..               ...   ...        ...
# 970          Mythic™   971  2V9R0Q292
# 971       ⚡Beiçudo™⚡   972  22JVR928C
# 972         Genesis™   973  2QYLJ9LVY
# 973             アナザー   974   CQ28URY0
# 974     新星 I вяaиѕ™♡   975   L9JRC9VL
# 975         ⚡️RJ10⚡️   976  9JLVPR9P0
# 976           naifer   977  9YLRU2QQQ
# 977      Lord Schnee   978   92UGYCPG
# 978   LMT | € MELO $   979   28CRGJQJ
# 979         Angelo10   980   UQ99G9JG
# 980      Chaos Semih   981    PC2YGJU
# 981           TimTim   982   2CQ0LU9V
# 982         Parzival   983   Q82UQYUJ
# 983         ALFonso✊   984    GQRJP2J
# 984           NΞCRO☠   985   80VV9GCR
# 985              WEN   986   QYPUPG2G
# 986       Skillz 2.0   987   GPUQRL0V
# 987           Tanner   988   LQYGP9L9
# 988  HİRAŞİMO KAAN ™   989   YRQR9C2C
# 989               逆境   990  8U9C8JRGJ
# 990            Joke    991    GCQUVQY
# 991     FixitralphYT   992   PVP0YVVY
# 992  Antonio Flores✊   993   YYJVJQPQ
# 993            Messi   994  8RCPVQYU9
# 994          壽山垃圾學店仔   995   RVU80VUG
# 995    Nova I sergio   996  2RJ9JY0LQ
# 996     ☺︎︎ドズルちゃん☺︎︎   997  8V9UJ90RR
# 997             だらけ隊   998  892RQ2LCU
# 998        PK I Frio   999  22V09GYRG
# 999        神ＮＥＰＴＵＮＯ™  1000  2GJ290C9Q
#
# [1000 rows x 3 columns]

# %%
try_df.to_csv('../data/Top_Players.csv')
